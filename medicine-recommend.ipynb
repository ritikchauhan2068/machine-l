# %%
# import libraries

import numpy as np
import pandas as pd

# %%
medicines = pd.read_csv('medicine.csv')

# %%
medicines.head()
# Out:
#    index                                          Drug_Name Reason  \
# 0      1               A CN Gel(Topical) 20gmA CN Soap 75gm   Acne
# 1      2  A Ret 0.05% Gel 20gmA Ret 0.1% Gel 20gmA Ret 0...   Acne
# 2      3                             ACGEL CL NANO Gel 15gm   Acne
# 3      4                                ACGEL NANO Gel 15gm   Acne
# 4      5                              Acleen 1% Lotion 25ml   Acne
#
#                                          Description
# 0                      Mild to moderate acne (spots)
# 1  A RET 0.025% is a prescription medicine that i...
# 2  It is used to treat acne vulgaris in people 12...
# 3  It is used to treat acne vulgaris in people 12...
# 4  treat the most severe form of acne (nodular ac...

# %%
s=medicines.Reason

# %%
def medication_chatbot(user_input):
    user_input_lower = user_input.lower()

    # Check if the user input matches any medication names in the dataset
    matching_medications = medicines[medicines['Reason'].str.lower().isin([user_input_lower])]

    # Check if there are any matching medications
    if not matching_medications.empty:
        # Display information about the matching medication(s)
        response = f"Here is information about the medication matching your input '{user_input}':\n"
        for index, row in matching_medications.iterrows():
            response += f"{row['Drug_Name']}: {row['Description']}\n"
        return response
    else:
        # If no direct match, provide a generic response or ask for more details
        return "I'm a simple medication chatbot. Please provide more details for personalized recommendations."

# Example usage
user_input = "Fever"
chatbot_response = medication_chatbot(user_input)
print(chatbot_response)
# Out:
# Here is information about the medication matching your input 'Fever':
# 1000 Para 1000mg Tablet 12'S: short-term treatment of fever
# Aalcetamol 1000mg Infusion 100ml: short-term treatment of fever
# ACETO 250mg Syrup 60ml: short-term treatment of fever
# Agpar 125mg Suspension 450ml: short-term treatment of fever
# ALGINA 500MG TABLET 10'S: short-term treatment of fever
# AMIDOL Tablet 10's: short-term treatment of fever
# Anaflam P Suspension 100ml: short-term treatment of fever
# Anglopar 125mg Drops 15mlAnglopar 500mg Tablet 10'SAnglopar 125mg Syrup 60mlAnglopar 650mg Tablet 10'S: short-term treatment of fever
# Babygesic 250mg Syrup 60mlBabygesic 125mg Syrup 60ml: short-term treatment of fever
# Bestogesic Fast 650mg Tablet 10'S: short-term treatment of fever
# Biocetamol 60mg Syrup 60mlBiocetamol 100mg Drops 10mlBiocetamol 150mg Injection 2ml: short-term treatment of fever
# Biopyrin 650mg Tablet 15'S: short-term treatment of fever
# Brikamol 250mg Syrup 60ml: short-term treatment of fever
# Brucet 400/333mg Tablet 3'S: short-term treatment of fever
# Cachpar 500mg Tablet 10'S: short-term treatment of fever
# Calipar 250mg Syrup 60ml: short-term treatment of fever
# Calpol 100mg Drops 15mlCalpol 650mg Tablet 10'SCalpol 500mg Tablet 500'SCalpol 500mg Tablet 10'S: short-term treatment of fever
# Calpol Plus Suspension 60mlCalpol Plus 400/325mg Tablet 10'S: used to treat migraine, fever, post-operative pain, dental pain, musculoskeletal and joint disorders
# Captol 650mg Tablet 10'S: used to treat headache migraine, fever, post-operative pain, dental pain, musculoskeletal and joint disorders
# Ultragin 125mg Syrup 60mlUltragin 500mg Tablet 10'S: it treatsÂ fever and pain, associated with common childhood disorders, tonsilitis, upper respiratory tract infection,
# Ultrapyrin 500mg Tablet 10'SUltrapyrin 250mg Suspension 60mlUltrapyrin 650mg Tablet 10'S: short-term treatment for fever, moderate pain, especially following surgery
# Welset 125mg Suspension 60mlWelset 500mg Tablet 10'S: it isÂ used for the relief of mild to moderate pain and feverish conditions such as headache, toothache, colds, influenza, joint pain and period pains
# Winmol 125mg Syrup 60ml: used to treat headache migraine, fever, post-operative pain, dental pain, musculoskeletal and joint disorders
# XT Para 1000mg Infusion 100mlXT Para 250mg Suspension 60mlXT Para 1000mg Tablet 12'S: used to treat headache migraine, fever, post-operative pain, dental pain, musculoskeletal and joint disorders
# Xyfix 125mg Drops 15mlXyfix 250mg Suspension 60ml: Â fever and pain, associated with common childhood disorders, tonsilitis, upper respiratory tract infection,
# Xyfix Extend 500mg Tablet 10'S: it treatsÂ fever and pain, associated with common childhood disorders, tonsilitis, upper respiratory tract infection,
# Xyfix Rapid 650mg Tablet 10'SXyfix Rapid 500mg Tablet 10'S: used to reduce a fever (high temperature)
# Xykaa 125mg Drops 15mlXykaa 250mg Suspension 60ml: used for mild to moderate pain including fever, headache, migraine, nerve pain, toothache, sore throat, period pains and general aches and pains
# Xypar 500mg Tablet 10'S: used to relieve the symptoms of fever, cold and flu
# Xytroy 650mg Tablet 10'S: used to treat headache migraine, fever, post-operative pain, dental pain, musculoskeletal and joint disorders
# Xytroy Rapid 500mg Tablet 10'S: Â fever and pain, associated with common childhood disorders, tonsilitis, upper respiratory tract infection,
# ZEPARA Suspension 60ml: it treatsÂ fever and pain, associated with common childhood disorders, tonsilitis, upper respiratory tract infection,
# ZEPARA XT 650mg Tablet 10's: short-term treatment for fever, moderate pain, especially following surgery
# Zukamin Plus Drops 15ml: used to treat headache migraine, fever, post-operative pain, dental pain, musculoskeletal and joint disorders

# %%
medicines.Drug_Name.unique()
# Out:
# array(['A CN Gel(Topical) 20gmA CN Soap 75gm',
#        'A Ret 0.05% Gel 20gmA Ret 0.1% Gel 20gmA Ret 0.025% Gel 20gm',
#        'ACGEL CL NANO Gel 15gm', ..., 'Wokadine M Onit 10gm',
#        'Wound Fix Solution 100ml', 'Wounsol Ointment 15gm'], dtype=object)

# %%
medicines.shape
# Out:
# (9720, 4)

# %%
pd.

# %%
medicines.isnull().sum()
# Out:
# index          0
# Drug_Name      0
# Reason         0
# Description    0
# dtype: int64

# %%
medicines.dropna(inplace=True)

# %%
medicines.duplicated().sum()
# Out:
# 0

# %%
medicines['Description']
# Out:
# 0                           Mild to moderate acne (spots)
# 1       A RET 0.025% is a prescription medicine that i...
# 2       It is used to treat acne vulgaris in people 12...
# 3       It is used to treat acne vulgaris in people 12...
# 4       treat the most severe form of acne (nodular ac...
#                               ...
# 9715                              used for treating warts
# 9716                        used to soften the skin cells
# 9717                                       used for scars
# 9718                                      used for wounds
# 9719    used to treat and remove raised warts (usually...
# Name: Description, Length: 9720, dtype: object

# %%
medicines['Description'].apply(lambda x:x.split())
# Out:
# 0                     [Mild, to, moderate, acne, (spots)]
# 1       [A, RET, 0.025%, is, a, prescription, medicine...
# 2       [It, is, used, to, treat, acne, vulgaris, in, ...
# 3       [It, is, used, to, treat, acne, vulgaris, in, ...
# 4       [treat, the, most, severe, form, of, acne, (no...
#                               ...
# 9715                         [used, for, treating, warts]
# 9716                 [used, to, soften, the, skin, cells]
# 9717                                   [used, for, scars]
# 9718                                  [used, for, wounds]
# 9719    [used, to, treat, and, remove, raised, warts, ...
# Name: Description, Length: 9720, dtype: object

# %%
medicines['Reason'] = medicines['Reason'].apply(lambda x:x.split())
medicines['Description'] = medicines['Description'].apply(lambda x:x.split())

# %%
medicines['Description'] = medicines['Description'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
medicines['Description'] = medicines['Description'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
medicines['tags'] = medicines['Description'] + medicines['Reason']

# %%
new_df = medicines[['index','Drug_Name','tags']]

# %%
new_df
# Out:
#       index                                          Drug_Name  \
# 0         1               A CN Gel(Topical) 20gmA CN Soap 75gm
# 1         2  A Ret 0.05% Gel 20gmA Ret 0.1% Gel 20gmA Ret 0...
# 2         3                             ACGEL CL NANO Gel 15gm
# 3         4                                ACGEL NANO Gel 15gm
# 4         5                              Acleen 1% Lotion 25ml
# ...     ...                                                ...
# 9715   9716                                T Muce Ointment 5gm
# 9716   9717  Wokadine 10% Solution 100mlWokadine Solution 5...
# 9717   9718                               Wokadine M Onit 10gm
# 9718   9719                           Wound Fix Solution 100ml
# 9719   9720                              Wounsol Ointment 15gm
#
#                                                    tags
# 0             [Mild, to, moderate, acne, (spots), Acne]
# 1     [A, RET, 0.025%, is, a, prescription, medicine...
# 2     [It, is, used, to, treat, acne, vulgaris, in, ...
# 3     [It, is, used, to, treat, acne, vulgaris, in, ...
# 4     [treat, the, most, severe, form, of, acne, (no...
# ...                                                 ...
# 9715                [used, for, treating, warts, Wound]
# 9716        [used, to, soften, the, skin, cells, Wound]
# 9717                          [used, for, scars, Wound]
# 9718                         [used, for, wounds, Wound]
# 9719  [used, to, treat, and, remove, raised, warts, ...
#
# [9720 rows x 3 columns]

# %%
new_df['tags'].apply(lambda x:" ".join(x))
# Out:
# 0       m i l d   t o   m o d e r   a c n   ( s p o t ...
# 1       a   r e t   0 . 0 2 5 %   i s   a   p r e s c ...
# 2       i t   i s   u s e   t o   t r e a t   a c n   ...
# 3       i t   i s   u s e   t o   t r e a t   a c n   ...
# 4       t r e a t   t h e   m o s t   s e v e r   f o ...
#                               ...
# 9715      u s e   f o r   t r e a t   w a r t   w o u n d
# 9716    u s e   t o   s o f t e n   t h e   s k i n   ...
# 9717                  u s e   f o r   s c a r   w o u n d
# 9718                u s e   f o r   w o u n d   w o u n d
# 9719    u s e   t o   t r e a t   a n d   r e m o v   ...
# Name: tags, Length: 9720, dtype: object

# %%
new_df
# Out:
#       index                                          Drug_Name  \
# 0         1               A CN Gel(Topical) 20gmA CN Soap 75gm
# 1         2  A Ret 0.05% Gel 20gmA Ret 0.1% Gel 20gmA Ret 0...
# 2         3                             ACGEL CL NANO Gel 15gm
# 3         4                                ACGEL NANO Gel 15gm
# 4         5                              Acleen 1% Lotion 25ml
# ...     ...                                                ...
# 9715   9716                                T Muce Ointment 5gm
# 9716   9717  Wokadine 10% Solution 100mlWokadine Solution 5...
# 9717   9718                               Wokadine M Onit 10gm
# 9718   9719                           Wound Fix Solution 100ml
# 9719   9720                              Wounsol Ointment 15gm
#
#                                                    tags
# 0             [Mild, to, moderate, acne, (spots), Acne]
# 1     [A, RET, 0.025%, is, a, prescription, medicine...
# 2     [It, is, used, to, treat, acne, vulgaris, in, ...
# 3     [It, is, used, to, treat, acne, vulgaris, in, ...
# 4     [treat, the, most, severe, form, of, acne, (no...
# ...                                                 ...
# 9715                [used, for, treating, warts, Wound]
# 9716        [used, to, soften, the, skin, cells, Wound]
# 9717                          [used, for, scars, Wound]
# 9718                         [used, for, wounds, Wound]
# 9719  [used, to, treat, and, remove, raised, warts, ...
#
# [9720 rows x 3 columns]

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:" ".join(x))
# Out:
# C:\Users\User 2\AppData\Local\Temp\ipykernel_13548\3089450492.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x:" ".join(x))

# %%
new_df
# Out:
#       index                                          Drug_Name  \
# 0         1               A CN Gel(Topical) 20gmA CN Soap 75gm
# 1         2  A Ret 0.05% Gel 20gmA Ret 0.1% Gel 20gmA Ret 0...
# 2         3                             ACGEL CL NANO Gel 15gm
# 3         4                                ACGEL NANO Gel 15gm
# 4         5                              Acleen 1% Lotion 25ml
# ...     ...                                                ...
# 9715   9716                                T Muce Ointment 5gm
# 9716   9717  Wokadine 10% Solution 100mlWokadine Solution 5...
# 9717   9718                               Wokadine M Onit 10gm
# 9718   9719                           Wound Fix Solution 100ml
# 9719   9720                              Wounsol Ointment 15gm
#
#                                                    tags
# 0                    Mild to moderate acne (spots) Acne
# 1     A RET 0.025% is a prescription medicine that i...
# 2     It is used to treat acne vulgaris in people 12...
# 3     It is used to treat acne vulgaris in people 12...
# 4     treat the most severe form of acne (nodular ac...
# ...                                                 ...
# 9715                      used for treating warts Wound
# 9716                used to soften the skin cells Wound
# 9717                               used for scars Wound
# 9718                              used for wounds Wound
# 9719  used to treat and remove raised warts (usually...
#
# [9720 rows x 3 columns]

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())
# Out:
# C:\Users\User 2\AppData\Local\Temp\ipykernel_13548\3214958533.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())

# %%
new_df
# Out:
#       index                                          Drug_Name  \
# 0         1               A CN Gel(Topical) 20gmA CN Soap 75gm
# 1         2  A Ret 0.05% Gel 20gmA Ret 0.1% Gel 20gmA Ret 0...
# 2         3                             ACGEL CL NANO Gel 15gm
# 3         4                                ACGEL NANO Gel 15gm
# 4         5                              Acleen 1% Lotion 25ml
# ...     ...                                                ...
# 9715   9716                                T Muce Ointment 5gm
# 9716   9717  Wokadine 10% Solution 100mlWokadine Solution 5...
# 9717   9718                               Wokadine M Onit 10gm
# 9718   9719                           Wound Fix Solution 100ml
# 9719   9720                              Wounsol Ointment 15gm
#
#                                                    tags
# 0                    mild to moderate acne (spots) acne
# 1     a ret 0.025% is a prescription medicine that i...
# 2     it is used to treat acne vulgaris in people 12...
# 3     it is used to treat acne vulgaris in people 12...
# 4     treat the most severe form of acne (nodular ac...
# ...                                                 ...
# 9715                      used for treating warts wound
# 9716                used to soften the skin cells wound
# 9717                               used for scars wound
# 9718                              used for wounds wound
# 9719  used to treat and remove raised warts (usually...
#
# [9720 rows x 3 columns]

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\user 2\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: tqdm in c:\users\user 2\anaconda3\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\user 2\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: joblib in c:\users\user 2\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: click in c:\users\user 2\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: colorama in c:\users\user 2\anaconda3\lib\site-packages (from click->nltk) (0.4.5)

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
# !pip install -U scikit-learn scipy matplotlib
# Out:
# Requirement already satisfied: scikit-learn in c:\users\user 2\anaconda3\lib\site-packages (1.0.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.3.2-cp39-cp39-win_amd64.whl (9.3 MB)
#      ---------------------------------------- 9.3/9.3 MB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: scipy in c:\users\user 2\anaconda3\lib\site-packages (1.9.1)
# Collecting scipy
#   Downloading scipy-1.11.4-cp39-cp39-win_amd64.whl (44.3 MB)
#      ---------------------------------------- 44.3/44.3 MB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in c:\users\user 2\anaconda3\lib\site-packages (3.5.2)
# Collecting matplotlib
#   Downloading matplotlib-3.8.2-cp39-cp39-win_amd64.whl (7.6 MB)
#      ---------------------------------------- 7.6/7.6 MB 15.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\user 2\anaconda3\lib\site-packages (from scikit-learn) (1.21.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\user 2\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Collecting joblib>=1.1.1
#   Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#      ------------------------------------- 302.2/302.2 kB 18.2 MB/s eta 0:00:00
# Collecting numpy<2.0,>=1.17.3
#   Downloading numpy-1.26.2-cp39-cp39-win_amd64.whl (15.8 MB)
#      --------------------------------------- 15.8/15.8 MB 15.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\user 2\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=8 in c:\users\user 2\anaconda3\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user 2\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user 2\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.1.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user 2\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.2.0-cp39-cp39-win_amd64.whl (181 kB)
#      ------------------------------------- 181.9/181.9 kB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user 2\anaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\user 2\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\user 2\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.8.0)
# Requirement already satisfied: six>=1.5 in c:\users\user 2\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: numpy, joblib, importlib-resources, scipy, contourpy, scikit-learn, matplotlib
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.0
#     Uninstalling joblib-1.1.0:
#       Successfully uninstalled joblib-1.1.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.9.1
#     Uninstalling scipy-1.9.1:
#       Successfully uninstalled scipy-1.9.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.0.2
#     Uninstalling scikit-learn-1.0.2:
#       Successfully uninstalled scikit-learn-1.0.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.5.2
#     Uninstalling matplotlib-3.5.2:
#       Successfully uninstalled matplotlib-3.5.2
# Successfully installed contourpy-1.2.0 importlib-resources-6.1.1 joblib-1.3.2 matplotlib-3.8.2 numpy-1.26.2 scikit-learn-1.3.2 scipy-1.11.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.6.0 requires daal==2021.4.0, which is not installed.
# ydata-profiling 4.5.1 requires numpy<1.24,>=1.16.0, but you have numpy 1.26.2 which is incompatible.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.26.2 which is incompatible.

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(stop_words='english',max_features=5000)

# %%
def my(text):
  y = []

  for i in text.split():
    y.append(ps.my(i))

  return " ".join(y)

# %%
new_df['tags'] = new_df['tags'].apply(my)
# Out:
# C:\Users\User 2\AppData\Local\Temp\ipykernel_13548\3213734980.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(stem)

# %%
cv.fit_transform(new_df['tags']).toarray().shape
# Out:
# (9720, 806)

# %%
vectors = cv.fit_transform(new_df['tags']).toarray()

# %%
cv.get_feature_names()
# Out:
# C:\Users\User 2\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   return fun(*args, **kwargs)
# ['025',
#  '12',
#  '16',
#  '18',
#  'abdomin',
#  'abl',
#  'ach',
#  'acid',
#  'acn',
#  'acne',
#  'acquir',
#  'action',
#  'activ',
#  'acut',
#  'acute',
#  'adequ',
#  'adhd',
#  'adjunct',
#  'adolesc',
#  'adult',
#  'adults',
#  'affect',
#  'ag',
#  'age',
#  'aids',
#  'allerg',
#  'allergen',
#  'allergi',
#  'allow',
#  'alon',
#  'alzheim',
#  'alzheimer',
#  'alzheimerâ',
#  'amoebiasi',
#  'anaemia',
#  'anal',
#  'angina',
#  'angl',
#  'ani',
#  'ankylos',
#  'anorexia',
#  'anoth',
#  'anti',
#  'antioxid',
#  'antipsychot',
#  'antiretrovir',
#  'anxieti',
#  'anxiou',
#  'anxious',
#  'apnoea',
#  'appear',
#  'appetit',
#  'appetite',
#  'appli',
#  'appropri',
#  'area',
#  'arrhythmia',
#  'arrhythmiasi',
#  'arteri',
#  'arthralgia',
#  'arthriti',
#  'associ',
#  'atherothrombot',
#  'athleteâ',
#  'atop',
#  'atrial',
#  'attack',
#  'awak',
#  'b1',
#  'b2',
#  'b3',
#  'b5',
#  'b6',
#  'babi',
#  'backache',
#  'bacteri',
#  'bacteria',
#  'balanc',
#  'balanitis',
#  'bandag',
#  'becom',
#  'behaviour',
#  'beliefs',
#  'benefit',
#  'beta',
#  'biliari',
#  'biotin',
#  'bite',
#  'blackhead',
#  'blackheads',
#  'bleaches',
#  'bleed',
#  'bloating',
#  'block',
#  'blood',
#  'bodi',
#  'bodyâ',
#  'bon',
#  'bone',
#  'bones',
#  'bowel',
#  'brain',
#  'breakdown',
#  'breath',
#  'brighten',
#  'bronchiti',
#  'brown',
#  'bursitis',
#  'calcium',
#  'calm',
#  'cancer',
#  'candid',
#  'candidiasis',
#  'canâ',
#  'carbohydr',
#  'cardiovascular',
#  'care',
#  'carrier',
#  'cartilag',
#  'case',
#  'cases',
#  'cataract',
#  'caus',
#  'cavity',
#  'cell',
#  'certain',
#  'chanc',
#  'chang',
#  'characteris',
#  'chemic',
#  'chemotherapi',
#  'chest',
#  'chickenpox',
#  'childhood',
#  'children',
#  'chlosma',
#  'cholesterol',
#  'chronic',
#  'clean',
#  'cleaner',
#  'cleanser',
#  'clear',
#  'clot',
#  'cmv',
#  'cold',
#  'colds',
#  'colic',
#  'colon',
#  'colorect',
#  'coma',
#  'combin',
#  'common',
#  'complet',
#  'complexion',
#  'concomit',
#  'condit',
#  'conditions',
#  'confused',
#  'confusion',
#  'congestion',
#  'conjunct',
#  'consciousness',
#  'consid',
#  'consist',
#  'constip',
#  'constipation',
#  'constipationâ',
#  'continu',
#  'contracept',
#  'control',
#  'contusion',
#  'convent',
#  'convulsion',
#  'corpori',
#  'corticosteroid',
#  'cough',
#  'cramp',
#  'cream',
#  'cruri',
#  'cushion',
#  'cycl',
#  'cytomegaloviru',
#  'cytoprotect',
#  'd3',
#  'daili',
#  'damag',
#  'dandruff',
#  'dark',
#  'death',
#  'decreas',
#  'defici',
#  'degrad',
#  'degre',
#  'delay',
#  'demand',
#  'dementia',
#  'dental',
#  'deposit',
#  'depress',
#  'depressed',
#  'dermat',
#  'deterg',
#  'diabet',
#  'diagnost',
#  'diarrhea',
#  'diarrhoea',
#  'diet',
#  'differ',
#  'difficult',
#  'difficulti',
#  'digest',
#  'digestion',
#  'dilate',
#  'discolor',
#  'discoloured',
#  'diseas',
#  'disord',
#  'disorder',
#  'disorders',
#  'displac',
#  'distens',
#  'dizzi',
#  'doctor',
#  'doe',
#  'drain',
#  'drained',
#  'dri',
#  'drop',
#  'drowsi',
#  'drugs',
#  'dull',
#  'dure',
#  'dysmenorrhea',
#  'ear',
#  'ears',
#  'eczema',
#  'effect',
#  'effects',
#  'elbow',
#  'element',
#  'emot',
#  'encephalopathi',
#  'endometriosi',
#  'energi',
#  'energy',
#  'enhanc',
#  'enlarg',
#  'enzym',
#  'enzyme',
#  'epicondylitis',
#  'episod',
#  'especi',
#  'essenti',
#  'event',
#  'excess',
#  'exercis',
#  'exfoli',
#  'exocrin',
#  'extern',
#  'extra',
#  'eye',
#  'eyes',
#  'face',
#  'fade',
#  'fail',
#  'failur',
#  'failure',
#  'fast',
#  'fat',
#  'fatigue',
#  'fats',
#  'fatti',
#  'febril',
#  'feed',
#  'feel',
#  'feet',
#  'fever',
#  'feverish',
#  'fibril',
#  'fine',
#  'fissur',
#  'flat',
#  'flatul',
#  'flatulence',
#  'flexibl',
#  'flow',
#  'flu',
#  'fluid',
#  'flutter',
#  'focus',
#  'folic',
#  'follow',
#  'food',
#  'foot',
#  'form',
#  'format',
#  'free',
#  'fresh',
#  'friction',
#  'function',
#  'fungal',
#  'fungi',
#  'fungu',
#  'gain',
#  'gener',
#  'genit',
#  'gland',
#  'glaucoma',
#  'glow',
#  'gonorrhoea',
#  'good',
#  'gout',
#  'gradual',
#  'gravi',
#  'growth',
#  'guilty',
#  'gum',
#  'ha',
#  'haematopoiesi',
#  'haemorrhoid',
#  'haemorrhoidectomi',
#  'haemorrhoids',
#  'hair',
#  'hallucinations',
#  'hands',
#  'hard',
#  'hay',
#  'head',
#  'headach',
#  'headache',
#  'heal',
#  'health',
#  'healthy',
#  'hear',
#  'hearing',
#  'heart',
#  'heartbeat',
#  'help',
#  'hepat',
#  'herp',
#  'high',
#  'hiv',
#  'hives',
#  'hormon',
#  'hospit',
#  'human',
#  'hygien',
#  'hypercalcaemia',
#  'hyperparathyroid',
#  'hyperpigment',
#  'hyperpigmentation',
#  'hypertens',
#  'hypertension',
#  'hyperthyroid',
#  'hypertrophi',
#  'hypnosi',
#  'hypotens',
#  'hypothyroid',
#  'hypothyroidism',
#  'hyroid',
#  'ibs',
#  'immun',
#  'immunodefici',
#  'improv',
#  'improvesâ',
#  'includ',
#  'incoher',
#  'incomplet',
#  'increas',
#  'indic',
#  'indigest',
#  'induc',
#  'infect',
#  'infection',
#  'infections',
#  'infest',
#  'inflamm',
#  'inflammationâ',
#  'inflammatori',
#  'influenza',
#  'infrequ',
#  'inguinalis',
#  'inhal',
#  'inhibitor',
#  'injuri',
#  'inner',
#  'insect',
#  'insid',
#  'insomnia',
#  'insufficiencyâ',
#  'integr',
#  'intens',
#  'interdigit',
#  'intern',
#  'interrupt',
#  'intestin',
#  'intestinal',
#  'intoler',
#  'invas',
#  'involuntari',
#  'iodine',
#  'iritis',
#  'iron',
#  'irrit',
#  'isâ',
#  'itch',
#  'itâ',
#  'jewelleri',
#  'jock',
#  'joint',
#  'kidney',
#  'kit',
#  'knees',
#  'known',
#  'lack',
#  'lactat',
#  'lead',
#  'learning',
#  'left',
#  'level',
#  'lice',
#  'life',
#  'ligaments',
#  'line',
#  'lip',
#  'liquid',
#  'liv',
#  'live',
#  'liver',
#  'long',
#  'look',
#  'lose',
#  'loss',
#  'lotion',
#  'lower',
#  'lowersâ',
#  'lowerâ',
#  'lung',
#  'lvh',
#  'mainli',
#  'maintain',
#  'major',
#  'make',
#  'malari',
#  'malaria',
#  'malignancies',
#  'manag',
#  'manganese',
#  'mani',
#  'manuum',
#  'marrow',
#  'medic',
#  'medicin',
#  'melanin',
#  'melasma',
#  'mellitu',
#  'memori',
#  'men',
#  'mening',
#  'menopaus',
#  'mental',
#  'metabol',
#  'methyl',
#  'micronutri',
#  'migrain',
#  'migraine',
#  'mild',
#  'milk',
#  'miner',
#  'minor',
#  'mistaken',
#  'mobil',
#  'moder',
#  'moderate',
#  'moistur',
#  'molybdenum',
#  'motion',
#  'movement',
#  'movements',
#  'muscl',
#  'muscular',
#  'musculoskelet',
#  'myalgia',
#  'myasthenia',
#  'mydriasi',
#  'myeloid',
#  'narrow',
#  'nasal',
#  'natur',
#  'nausea',
#  'need',
#  'nephropathy',
#  'nerv',
#  'nervosa',
#  'nervousness',
#  'nettl',
#  'neuralgia',
#  'neutral',
#  'newborns',
#  'nodular',
#  'non',
#  'normal',
#  'nose',
#  'nutrient',
#  'nutrit',
#  'occur',
#  'ocular',
#  'ofâ',
#  'oili',
#  'older',
#  'onli',
#  'op',
#  'open',
#  'oper',
#  'oral',
#  'origin',
#  'osteoarthr',
#  'osteodystrophy',
#  'osteoporosi',
#  'oxid',
#  'oxidation',
#  'pah',
#  'pain',
#  'pancrea',
#  'paralys',
#  'parathyroid',
#  'parkinson',
#  'parkinsonâ',
#  'passag',
#  'patch',
#  'patches',
#  'patient',
#  'patientsâ',
#  'pectori',
#  'pectoris',
#  'pedis',
#  'pelvic',
#  'penil',
#  'peopl',
#  'peptid',
#  'period',
#  'physic',
#  'piles',
#  'pimpl',
#  'pimple',
#  'pityriasi',
#  'polysaccharid',
#  'portal',
#  'post',
#  'potent',
#  'power',
#  'pre',
#  'prednisolon',
#  'pregnanc',
#  'prematur',
#  'preoper',
#  'prescrib',
#  'prescript',
#  'present',
#  'pressur',
#  'prevent',
#  'prexia',
#  'primari',
#  'prinzmet',
#  'problem',
#  'procedur',
#  'process',
#  'proctiti',
#  'produc',
#  'product',
#  'progress',
#  'prolactin',
#  'promot',
#  'properti',
#  'protect',
#  'provid',
#  'pseudo',
#  'psychosi',
#  'psychosomat',
#  'pulmonari',
#  'pupil',
#  'pyrexia',
#  'rabi',
#  'radicals',
#  'radiculitis',
#  'rais',
#  'rarer',
#  'rash',
#  'react',
#  'reaction',
#  'receiv',
#  'recommend',
#  'red',
#  'reduc',
#  'reduct',
#  'refer',
#  'regener',
#  'regimen',
#  'relat',
#  'releief',
#  'relief',
#  'reliev',
#  'reliv',
#  'remov',
#  'renal',
#  'repair',
#  'replac',
#  'reproduct',
#  'resist',
#  'respiratori',
#  'respond',
#  'respons',
#  'restor',
#  'ret',
#  'retin',
#  'rheumat',
#  'ring',
#  'ringworm',
#  'root',
#  'rosacea',
#  'scabi',
#  'scali',
#  'scalp',
#  'scar',
#  'schizophren',
#  'schizophrenia',
#  'seborrh',
#  'sed',
#  'sedat',
#  'sens',
#  'sever',
#  'shingl',
#  'short',
#  'sick',
#  'sickness',
#  'silki',
#  'simpl',
#  'simplex',
#  'sinusitis',
#  'skelet',
#  'skin',
#  'skinâ',
#  'sleep',
#  'slow',
#  'small',
#  'smoke',
#  'smooth',
#  'soaps',
#  'soar',
#  'soft',
#  'soften',
#  'soothen',
#  'sore',
#  'sores',
#  'spasmod',
#  'speech',
#  'speed',
#  'spondyl',
#  'spot',
#  'spots',
#  'sprain',
#  'spread',
#  'stabil',
#  'starch',
#  'start',
#  'state',
#  'steroids',
#  'stiff',
#  'stomach',
#  'stools',
#  'stop',
#  'strains',
#  'strengthen',
#  'stroke',
#  'structur',
#  'substanc',
#  'suffer',
#  'sugar',
#  'sunburn',
#  'sunscreen',
#  'suppl',
#  'supplement',
#  'support',
#  'surgeri',
#  'surgeryâ',
#  'surgic',
#  'suspiciousness',
#  'sweat',
#  'swell',
#  'swelling',
#  'swollen',
#  'symptom',
#  'symptomat',
#  'symptoms',
#  'syndrom',
#  'synovi',
#  'synovitis',
#  'synthesi',
#  'synthet',
#  'syphilis',
#  'tablet',
#  'tachycardia',
#  'task',
#  'temperature',
#  'tender',
#  'tendonitis',
#  'tens',
#  'term',
#  'textur',
#  'therapi',
#  'therebi',
#  'thi',
#  'thing',
#  'throat',
#  'thrombolysi',
#  'thrush',
#  'thu',
#  'thyroid',
#  'thyroxin',
#  'time',
#  'tinea',
#  'tinnitus',
#  'tissu',
#  'tissues',
#  'toe',
#  'tone',
#  'tonsil',
#  'tonsilitis',
#  'tonsillectomi',
#  'toothach',
#  'toothache',
#  'topic',
#  'trace',
#  'tract',
#  'transmit',
#  'transplant',
#  'trauma',
#  'traumat',
#  'travel',
#  'treat',
#  'treatment',
#  'treatsâ',
#  'treatâ',
#  'tremor',
#  'triglycerid',
#  'tubercular',
#  'type',
#  'ulcer',
#  'unabl',
#  'unbalanc',
#  'uncompl',
#  'uneven',
#  'unstabl',
#  'unusu',
#  'unwant',
#  'upper',
#  'uptak',
#  'urate',
#  'uretericâ',
#  'uric',
#  'urinaryâ',
#  'use',
#  'uses',
#  'usual',
#  'uveiti',
#  'vaccin',
#  'vagin',
#  'variant',
#  'varieti',
#  'ventricular',
#  'verruca',
#  'versicolor',
#  'vertigo',
#  'vessel',
#  'viral',
#  'viru',
#  'virus',
#  'vitamin',
#  'vitamins',
#  'volume',
#  'vomit',
#  'vulgari',
#  'vulgarisâ',
#  'wall',
#  'wart',
#  'wash',
#  'weak',
#  'weaken',
#  'weight',
#  'wet',
#  'whichâ',
#  'whilst',
#  'white',
#  'widen',
#  'withdrawn',
#  'womb',
#  'women',
#  'work',
#  'worsen',
#  'wound',
#  'wrinkl',
#  'wrinkles',
#  'year',
#  'younger',
#  'zinc',
#  'œpancreat']

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_similarity(vectors)
# Out:
# array([[1.        , 0.25197632, 0.43643578, ..., 0.        , 0.        ,
#         0.        ],
#        [0.25197632, 1.        , 0.25660012, ..., 0.19245009, 0.1490712 ,
#         0.0860663 ],
#        [0.43643578, 0.25660012, 1.        , ..., 0.11111111, 0.0860663 ,
#         0.0993808 ],
#        ...,
#        [0.        , 0.19245009, 0.11111111, ..., 1.        , 0.77459667,
#         0.2981424 ],
#        [0.        , 0.1490712 , 0.0860663 , ..., 0.77459667, 1.        ,
#         0.34641016],
#        [0.        , 0.0860663 , 0.0993808 , ..., 0.2981424 , 0.34641016,
#         1.        ]])

# %%
similarity = cosine_similarity(vectors)

# %%
similarity[1]
# Out:
# array([0.25197632, 1.        , 0.25660012, ..., 0.19245009, 0.1490712 ,
#        0.0860663 ])

# %%
def recommendation(medicine):
    medicine_index = new_df[new_df['Drug_Name'] == medicine].index[0]
    distances = similarity[medicine_index]
    medicines_list = sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[1:6]
    
    for i in medicines_list:
        print(new_df.iloc[i[0]].Drug_Name)

# %%
recommend("Paracetamol 125mg Syrup 60mlParacetamol 500mg Tablet 10'S")
# Out:
# Oxypamol D Tablet 10'S
# Pacimol MF Tablet 10'S
# Painil Plus 100/500mg Tablet 10'S
# Pamagin Plus Gel 30gm
# Paracetamol 125mg Syrup 60mlParacetamol 500mg Tablet 10'S

# %%
import pickle

# %%
pickle.dump(new_df.to_dict(),open('medicine_dict.pkl','wb'))
pickle.dump(similarity,open('similarity.pkl','wb'))
